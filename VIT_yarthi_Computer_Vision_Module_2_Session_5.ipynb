# %% [markdown]
# Histrogram Equalization

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Reading Image

# %%
img = cv2.imread('/content/Einstien.jpg')
imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)

# %% [markdown]
# Histrogram Equalization Operation

# %%
dst = cv2.equalizeHist(imgGray)
dst = cv2.cvtColor(dst,cv2.COLOR_GRAY2BGR)
plt.imshow(dst)

# %%
import random
import pandas as pd

random.seed(1)

def generate_Pearl_millet_fake_data():
    return {
        'Types of Millets': 'Pearl millet (Pennisetum glaucum)',
        'Common Name': 'PEARL',
        'Category': 'Major',
        'Drought resistant': 1.0,
        'Flood Resistant': 0.0,
        'Temperature (C)': round(random.uniform(30, 34), 2),  # Min Temperature (ºC), Max Temperature (ºC)
        'pH level of the soil': random.uniform(6, 7),  # pH level of the soil Min, pH level of the soil Max
        'Soil type': random.choice(["LC", "SL"]),
        'Soil Salinity (dS/m)': random.uniform(11, 12),
        'Rainfall Required (cm)': random.randint(20, 60),
        'Altitude range (m)': random.randint(0, 2700),
        'Soil Temperature (ºC)': '',
        'Soil moisture': '80%',
        'Light Duration (hours)': '20%',
        'Land usage for each crop (t/ha)': '1',
        'Seeding Rate (kg/ha)': '2',
        'Maturity time (days)': random.randint(60, 70),
        'Planting Depth (cm)': '',
        'Planting Geometry (cm x cm)': '',
        'Protein (g)': '10.96',
        'Fat (g)': '5.43',
        'Ash (g)': '1.37',
        'Crude Fibre (g)': '11.49',
        'Carbo-hydrates (g)': '61.78',
        'Energy (kcal)': '348',
        'Calcium (mg)': '27.35',
        'Iron (mg)': '6.42',
        'Thiamine (mg)': '0.25',
        'Ribo-flavin (mg)': '0.2',
        'Nia-cin (mg)': '0.86'
    }

Pearl_millet_fake_data = [generate_Pearl_millet_fake_data() for _ in range(1500)]
DF_Pearl_millet_fake_data = pd.DataFrame(Pearl_millet_fake_data)
